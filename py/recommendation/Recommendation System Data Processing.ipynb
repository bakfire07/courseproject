# %%
import math
import pprint
# get the data
fs = open('/Users/balamurali/Downloads/Session15 - Form responses 1.tsv','r')
labels =  fs.readline().strip().split('\t')[2:]

# create the matrix representation
data = dict()
for line in fs:
    temp_arr = line.strip().split('\t')
    count  = 0
    temp = dict()
    for item_score in temp_arr[2:]:
        if len(item_score.strip())>0 and count < len(labels):
            temp[labels[count].strip()] =  float(item_score)
        count+=1
    data[temp_arr[1].strip()] = temp

pprint.pprint (data)
fs.close()
# Out:
# {'Rohan.raman17@iimv.ac.in': {'B2B Marketing': 4.0,
#                               'Corporate Strategy': 5.0,
#                               'General Commercial Knowledge': 4.0,
#                               'Project Management': 3.0,
#                               'Research for Marketing Decisions': 4.0,
#                               'Spreadsheets for Business & Personal Productivity': 1.0},
#  'Shanthan.nimmagadda17@iimv.ac.in': {'B2B Marketing': 5.0,
#                                       'Banking, Financial Markets and Systems': 5.0,
#                                       'Consumer Behaviour': 5.0,
#                                       'Project Management': 4.0,
#                                       'Research for Marketing Decisions': 4.0},
#  'aadesh.fathwani17@iimv.ac.in': {'B2B Marketing': 4.0,
#                                   'Banking, Financial Markets and Systems': 5.0,
#                                   'Consumer Behaviour': 4.0,
#                                   'Project Management': 3.0,
#                                   'Research for Marketing Decisions': 4.0},
#  'adithya.gogikar17@iimv.ac.in': {'B2B Marketing': 4.0,
#                                   'Banking, Financial Markets and Systems': 5.0,
#                                   'Corporate Strategy': 5.0,
#                                   'Project Management': 2.0,
#                                   'Research for Marketing Decisions': 4.0},
#  'alankruta.patnaik17@iimv.ac.in': {'B2B Marketing': 2.0,
#                                     'Brand Management': 4.0,
#                                     'Business Data Mining & Decision Models': 5.0,
#                                     'Corporate Strategy': 5.0,
#                                     'General Commercial Knowledge': 5.0,
#                                     'Project Management': 5.0,
#                                     'Research for Marketing Decisions': 5.0,
#                                     'Spreadsheets for Business & Personal Productivity': 3.0},
#  'amit.maurya17@iimv.ac.in': {'B2B Marketing': 4.0,
#                               'Banking, Financial Markets and Systems': 5.0,
#                               'Business Data Mining & Decision Models': 2.0,
#                               'Consumer Behaviour': 4.0,
#                               'Project Management': 3.0,
#                               'Research for Marketing Decisions': 4.0},
#  'arnav.sharma17@iimv.ac.in': {'B2B Marketing': 2.0,
#                                'Banking, Financial Markets and Systems': 5.0,
#                                'Corporate Strategy': 4.0,
#                                'Project Management': 1.0,
#                                'Research for Marketing Decisions': 3.0},
#  'brahmadeb.mukherjee17@iimv.ac.in': {'B2B Marketing': 3.0,
#                                       'Banking, Financial Markets and Systems': 5.0,
#                                       'General Commercial Knowledge': 4.0,
#                                       'Project Management': 3.0,
#                                       'Research for Marketing Decisions': 4.0,
#                                       'Spreadsheets for Business & Personal Productivity': 3.0},
#  'elakkiya.n17@iimv.ac.in': {'B2B Marketing': 5.0,
#                              'Banking, Financial Markets and Systems': 5.0,
#                              'Consumer Behaviour': 5.0,
#                              'Project Management': 4.0,
#                              'Research for Marketing Decisions': 4.0},
#  'himanth.esarapu17@iimv.ac.in': {'B2B Marketing': 5.0,
#                                   'Banking, Financial Markets and Systems': 5.0,
#                                   'Consumer Behaviour': 5.0,
#                                   'Project Management': 3.0,
#                                   'Research for Marketing Decisions': 5.0},
#  'kartheek.pochampally17@iimv.ac.in': {'B2B Marketing': 5.0,
#                                        'Banking, Financial Markets and Systems': 5.0,
#                                        'Brand Management': 5.0,
#                                        'Business Data Mining & Decision Models': 5.0,
#                                        'Consumer Behaviour': 5.0,
#                                        'Corporate Strategy': 1.0,
#                                        'Financial Derivatives': 5.0,
#                                        'General Commercial Knowledge': 1.0,
#                                        'Management Control System': 1.0,
#                                        'Project Management': 5.0,
#                                        'Research for Marketing Decisions': 5.0,
#                                        'Spreadsheets for Business & Personal Productivity': 1.0},
#  'katta.nija17@iimv.ac.in': {'B2B Marketing': 4.0,
#                              'Banking, Financial Markets and Systems': 5.0,
#                              'Consumer Behaviour': 4.0,
#                              'Project Management': 3.0,
#                              'Research for Marketing Decisions': 4.0},
#  'kunal.ahirwal17@iimv.ac.in': {'B2B Marketing': 4.0,
#                                 'Corporate Strategy': 4.0,
#                                 'Project Management': 5.0,
#                                 'Research for Marketing Decisions': 3.0,
#                                 'Spreadsheets for Business & Personal Productivity': 4.0},
#  'kundi.pavan17@iimv.ac.in': {'Business Data Mining & Decision Models': 3.0,
#                               'Consumer Behaviour': 5.0,
#                               'Corporate Strategy': 1.0,
#                               'Financial Derivatives': 2.0,
#                               'General Commercial Knowledge': 4.0},
#  'manish.namana17@iimv.ac.in': {'B2B Marketing': 5.0,
#                                 'Banking, Financial Markets and Systems': 5.0,
#                                 'Brand Management': 5.0,
#                                 'Business Data Mining & Decision Models': 4.0,
#                                 'Consumer Behaviour': 5.0,
#                                 'Corporate Strategy': 2.0,
#                                 'Financial Derivatives': 1.0,
#                                 'General Commercial Knowledge': 1.0,
#                                 'Management Control System': 1.0,
#                                 'Project Management': 3.0,
#                                 'Research for Marketing Decisions': 4.0,
#                                 'Spreadsheets for Business & Personal Productivity': 2.0},
#  'manjira.haldar17@iimv.ac.in': {'B2B Marketing': 5.0,
#                                  'Banking, Financial Markets and Systems': 5.0,
#                                  'Business Data Mining & Decision Models': 4.0,
#                                  'Consumer Behaviour': 3.0,
#                                  'Financial Derivatives': 5.0,
#                                  'General Commercial Knowledge': 3.0,
#                                  'Research for Marketing Decisions': 4.0},
#  'nikhil.kumar17@iimv.ac.in': {'B2B Marketing': 4.0,
#                                'Banking, Financial Markets and Systems': 5.0,
#                                'Business Data Mining & Decision Models': 2.0,
#                                'Project Management': 4.0,
#                                'Research for Marketing Decisions': 5.0,
#                                'Spreadsheets for Business & Personal Productivity': 5.0},
#  'rahul.singh17@iimv.ac.in': {'B2B Marketing': 5.0,
#                               'Banking, Financial Markets and Systems': 5.0,
#                               'General Commercial Knowledge': 5.0,
#                               'Project Management': 5.0,
#                               'Research for Marketing Decisions': 5.0,
#                               'Spreadsheets for Business & Personal Productivity': 5.0},
#  'ravindra.pal17@iimv.ac': {'B2B Marketing': 3.0,
#                             'Consumer Behaviour': 5.0,
#                             'Corporate Strategy': 3.0,
#                             'Project Management': 5.0,
#                             'Research for Marketing Decisions': 5.0},
#  'sabhapathi.reddy17@iimv.ac.in': {'B2B Marketing': 5.0,
#                                    'Banking, Financial Markets and Systems': 5.0,
#                                    'Consumer Behaviour': 5.0,
#                                    'Project Management': 4.0,
#                                    'Research for Marketing Decisions': 4.0},
#  'saikam.raghava17@iimv.ac.in': {'B2B Marketing': 4.0,
#                                  'Banking, Financial Markets and Systems': 4.0,
#                                  'Consumer Behaviour': 4.0,
#                                  'Project Management': 4.0,
#                                  'Research for Marketing Decisions': 4.0},
#  'sriharsha.palvadi17@iimv.ac.in': {'B2B Marketing': 3.0,
#                                     'Banking, Financial Markets and Systems': 5.0,
#                                     'General Commercial Knowledge': 3.0,
#                                     'Project Management': 3.0,
#                                     'Research for Marketing Decisions': 2.0,
#                                     'Spreadsheets for Business & Personal Productivity': 3.0},
#  'sumeet.kumar17@iimv.ac.in': {'B2B Marketing': 5.0,
#                                'Banking, Financial Markets and Systems': 5.0,
#                                'Business Data Mining & Decision Models': 5.0,
#                                'Consumer Behaviour': 5.0,
#                                'Project Management': 5.0,
#                                'Research for Marketing Decisions': 5.0},
#  'tanmoy.misra17@iimv.ac.in': {'Banking, Financial Markets and Systems': 5.0,
#                                'Corporate Strategy': 5.0,
#                                'Project Management': 4.0,
#                                'Research for Marketing Decisions': 4.0}}

# %%
data = {
	'Alan Perlis': { 
		'Artificial intelligence': 1.46, 
		'Systems programming': 5.0, 
		'Software engineering': 3.34, 
		'Databases': 2.32
	},

	'Marvin Minsky': { 
		'Artificial intelligence': 5.0, 
		'Systems programming': 2.54,
		'Computation': 4.32, 
		'Algorithms': 2.76
	},

	'John McCarthy': { 
		'Artificial intelligence': 5.0, 
		'Programming language theory': 4.72, 
		'Systems programming': 3.25, 
		'Concurrency': 3.61, 
		'Formal methods': 3.58,
		'Computation': 3.23, 
		'Algorithms': 3.03 
	},

	'Edsger Dijkstra': { 
		'Programming language theory': 4.34, 
		'Systems programming': 4.52,
		'Software engineering': 4.04, 
		'Concurrency': 3.97,
		'Formal methods': 5.0, 
		'Algorithms': 4.92 
	},

	'Donald Knuth': { 
		'Programming language theory': 4.33, 
		'Systems programming': 3.57,
		'Computation': 4.39, 
		'Algorithms': 5.0 
	},

	'John Backus': { 
		'Programming language theory': 4.58, 
		'Systems programming': 4.43,
		'Software engineering': 4.38, 
		'Formal methods': 2.42, 
		'Databases': 2.80 
	},

	'Robert Floyd': { 
		'Programming language theory': 4.24, 
		'Systems programming': 2.17,
		'Concurrency': 2.92, 
		'Formal methods': 5.0, 
		'Computation': 3.18, 
		'Algorithms': 5.0 
	},

	'Tony Hoare': { 
		'Programming language theory': 4.64, 
		'Systems programming': 4.38,
		'Software engineering': 3.62, 
		'Concurrency': 4.88,
		'Formal methods': 4.72, 
		'Algorithms': 4.38
	},

	'Edgar Codd': { 
		'Systems programming': 4.60, 
		'Software engineering': 3.54,
		'Concurrency': 4.28, 
		'Formal methods': 1.53, 
		'Databases': 5.0
	},

	'Dennis Ritchie': { 
		'Programming language theory': 3.45, 
		'Systems programming': 5.0,
		'Software engineering': 4.83,
	},

	'Niklaus Wirth': { 
		'Programming language theory': 4.23, 
		'Systems programming': 4.22,
		'Software engineering': 4.74, 
		'Formal methods': 3.83, 
		'Algorithms': 3.95
	},

	'Robin Milner': { 
		'Programming language theory': 5.0, 
		'Systems programming': 1.66,
		'Concurrency': 4.62, 
		'Formal methods': 3.94,
	},

	'Leslie Lamport': { 
		'Programming language theory': 1.5, 
		'Systems programming': 2.76,
		'Software engineering': 3.76, 
		'Concurrency': 5.0,
		'Formal methods': 4.93, 
		'Algorithms': 4.63
	},

	'Michael Stonebraker': { 
		'Systems programming': 4.67, 
		'Software engineering': 3.86,
		'Concurrency': 4.14, 
		'Databases': 5.0,
	}
}

# %%
# similarity measures
def euclidean_similarity(person1, person2):

    common_ranked_items = [itm for itm in data[person1] if itm in data[person2]]
    rankings = [(data[person1][itm], data[person2][itm]) for itm in common_ranked_items]
    distance = [pow(rank[0] - rank[1], 2) for rank in rankings]

    return 1 / (1 + sum(distance))

def pearson_similarity(person1, person2):

    common_ranked_items = [itm for itm in data[person1] if itm in data[person2]]

    n = len(common_ranked_items)

    s1 = sum([data[person1][item] for item in common_ranked_items])
    s2 = sum([data[person2][item] for item in common_ranked_items])

    ss1 = sum([pow(data[person1][item], 2) for item in common_ranked_items])
    ss2 = sum([pow(data[person2][item], 2) for item in common_ranked_items])

    ps = sum([data[person1][item] * data[person2][item] for item in common_ranked_items])

    num = n * ps - (s1 * s2)

    den = math.sqrt((n * ss1 - math.pow(s1, 2)) * (n * ss2 - math.pow(s2, 2)))

    return (num / den) if den != 0 else 0

# %%
# find the recommendation
def recommend(person, bound, similarity=pearson_similarity):
    scores = [(similarity(person, other), other) for other in data if other != person]
    #print scores
    scores.sort()
    scores.reverse()
    scores = scores[0:bound]

    recomms = {}

    for sim, other in scores:
        ranked = data[other]
        print other
        for itm in ranked:
            if itm not in data[person]:
                weight = sim * ranked[itm]
                #print itm
                if itm in recomms:
                    s, weights = recomms[itm]
                    recomms[itm] = (s + sim, weights + [weight])
                else:
                    recomms[itm] = (sim, [weight])
                #print recomms[itm]
    for r in recomms:
        
        sim, item = recomms[r]
        #print sim,item
        if sim>0:
            recomms[r] = round(sum(item) / sim,1)

    return recomms

# %%
for person in data:
    print '\n' + person + '\n'
    pprint.pprint(recommend(person,5))
    print '\n' + '*'*60
# Out:
# manjira.haldar17@iimv.ac.in
#
# tanmoy.misra17@iimv.ac.in
# kunal.ahirwal17@iimv.ac.in
# kartheek.pochampally17@iimv.ac.in
# katta.nija17@iimv.ac.in
# aadesh.fathwani17@iimv.ac.in
# {'Brand Management': 5.0,
#  'Corporate Strategy': 3.7,
#  'Management Control System': 1.0,
#  'Project Management': 4.1,
#  'Spreadsheets for Business & Personal Productivity': 2.9}
#
# ************************************************************
#
# kartheek.pochampally17@iimv.ac.in
#
# manish.namana17@iimv.ac.in
# ravindra.pal17@iimv.ac
# manjira.haldar17@iimv.ac.in
# kundi.pavan17@iimv.ac.in
# brahmadeb.mukherjee17@iimv.ac.in
# {}
#
# ************************************************************
#
# katta.nija17@iimv.ac.in
#
# amit.maurya17@iimv.ac.in
# aadesh.fathwani17@iimv.ac.in
# Rohan.raman17@iimv.ac.in
# adithya.gogikar17@iimv.ac.in
# arnav.sharma17@iimv.ac.in
# {'Business Data Mining & Decision Models': 2.0,
#  'Corporate Strategy': 4.7,
#  'General Commercial Knowledge': 4.0,
#  'Spreadsheets for Business & Personal Productivity': 1.0}
#
# ************************************************************
#
# nikhil.kumar17@iimv.ac.in
#
# amit.maurya17@iimv.ac.in
# arnav.sharma17@iimv.ac.in
# katta.nija17@iimv.ac.in
# aadesh.fathwani17@iimv.ac.in
# adithya.gogikar17@iimv.ac.in
# {'Consumer Behaviour': 4.0, 'Corporate Strategy': 4.4}
#
# ************************************************************
#
# kunal.ahirwal17@iimv.ac.in
#
# manjira.haldar17@iimv.ac.in
# sriharsha.palvadi17@iimv.ac.in
# tanmoy.misra17@iimv.ac.in
# sumeet.kumar17@iimv.ac.in
# saikam.raghava17@iimv.ac.in
# {'Banking, Financial Markets and Systems': 5.0,
#  'Business Data Mining & Decision Models': 4.0,
#  'Consumer Behaviour': 3.0,
#  'Financial Derivatives': 5.0,
#  'General Commercial Knowledge': 3.0}
#
# ************************************************************
#
# aadesh.fathwani17@iimv.ac.in
#
# katta.nija17@iimv.ac.in
# amit.maurya17@iimv.ac.in
# Rohan.raman17@iimv.ac.in
# adithya.gogikar17@iimv.ac.in
# arnav.sharma17@iimv.ac.in
# {'Business Data Mining & Decision Models': 2.0,
#  'Corporate Strategy': 4.7,
#  'General Commercial Knowledge': 4.0,
#  'Spreadsheets for Business & Personal Productivity': 1.0}
#
# ************************************************************
#
# alankruta.patnaik17@iimv.ac.in
#
# brahmadeb.mukherjee17@iimv.ac.in
# ravindra.pal17@iimv.ac
# Rohan.raman17@iimv.ac.in
# arnav.sharma17@iimv.ac.in
# tanmoy.misra17@iimv.ac.in
# {'Banking, Financial Markets and Systems': 5.0, 'Consumer Behaviour': 5.0}
#
# ************************************************************
#
# Shanthan.nimmagadda17@iimv.ac.in
#
# tanmoy.misra17@iimv.ac.in
# sabhapathi.reddy17@iimv.ac.in
# elakkiya.n17@iimv.ac.in
# manish.namana17@iimv.ac.in
# sriharsha.palvadi17@iimv.ac.in
# {'Brand Management': 5.0,
#  'Business Data Mining & Decision Models': 4.0,
#  'Corporate Strategy': 3.6,
#  'Financial Derivatives': 1.0,
#  'General Commercial Knowledge': 1.9,
#  'Management Control System': 1.0,
#  'Spreadsheets for Business & Personal Productivity': 2.4}
#
# ************************************************************
#
# sriharsha.palvadi17@iimv.ac.in
#
# tanmoy.misra17@iimv.ac.in
# kunal.ahirwal17@iimv.ac.in
# sabhapathi.reddy17@iimv.ac.in
# elakkiya.n17@iimv.ac.in
# Shanthan.nimmagadda17@iimv.ac.in
# {'Consumer Behaviour': 5.0, 'Corporate Strategy': 4.5}
#
# ************************************************************
#
# tanmoy.misra17@iimv.ac.in
#
# sabhapathi.reddy17@iimv.ac.in
# manjira.haldar17@iimv.ac.in
# elakkiya.n17@iimv.ac.in
# Shanthan.nimmagadda17@iimv.ac.in
# sriharsha.palvadi17@iimv.ac.in
# {'B2B Marketing': 4.6,
#  'Business Data Mining & Decision Models': 4.0,
#  'Consumer Behaviour': 4.5,
#  'Financial Derivatives': 5.0,
#  'General Commercial Knowledge': 3.0,
#  'Spreadsheets for Business & Personal Productivity': 3.0}
#
# ************************************************************
#
# adithya.gogikar17@iimv.ac.in
#
# katta.nija17@iimv.ac.in
# amit.maurya17@iimv.ac.in
# aadesh.fathwani17@iimv.ac.in
# Rohan.raman17@iimv.ac.in
# himanth.esarapu17@iimv.ac.in
# {'Business Data Mining & Decision Models': 2.0,
#  'Consumer Behaviour': 4.2,
#  'General Commercial Knowledge': 4.0,
#  'Spreadsheets for Business & Personal Productivity': 1.0}
#
# ************************************************************
#
# saikam.raghava17@iimv.ac.in
#
# tanmoy.misra17@iimv.ac.in
# sumeet.kumar17@iimv.ac.in
# sriharsha.palvadi17@iimv.ac.in
# sabhapathi.reddy17@iimv.ac.in
# ravindra.pal17@iimv.ac
# {'Business Data Mining & Decision Models': (0, [0.0]),
#  'Corporate Strategy': (0, [0.0, 0.0]),
#  'General Commercial Knowledge': (0, [0.0]),
#  'Spreadsheets for Business & Personal Productivity': (0, [0.0])}
#
# ************************************************************
#
# elakkiya.n17@iimv.ac.in
#
# tanmoy.misra17@iimv.ac.in
# sabhapathi.reddy17@iimv.ac.in
# Shanthan.nimmagadda17@iimv.ac.in
# manish.namana17@iimv.ac.in
# sriharsha.palvadi17@iimv.ac.in
# {'Brand Management': 5.0,
#  'Business Data Mining & Decision Models': 4.0,
#  'Corporate Strategy': 3.6,
#  'Financial Derivatives': 1.0,
#  'General Commercial Knowledge': 1.9,
#  'Management Control System': 1.0,
#  'Spreadsheets for Business & Personal Productivity': 2.4}
#
# ************************************************************
#
# arnav.sharma17@iimv.ac.in
#
# brahmadeb.mukherjee17@iimv.ac.in
# katta.nija17@iimv.ac.in
# amit.maurya17@iimv.ac.in
# aadesh.fathwani17@iimv.ac.in
# Rohan.raman17@iimv.ac.in
# {'Business Data Mining & Decision Models': 2.0,
#  'Consumer Behaviour': 4.0,
#  'General Commercial Knowledge': 4.0,
#  'Spreadsheets for Business & Personal Productivity': 2.0}
#
# ************************************************************
#
# amit.maurya17@iimv.ac.in
#
# kundi.pavan17@iimv.ac.in
# katta.nija17@iimv.ac.in
# aadesh.fathwani17@iimv.ac.in
# Rohan.raman17@iimv.ac.in
# adithya.gogikar17@iimv.ac.in
# {'Corporate Strategy': 3.7,
#  'Financial Derivatives': 2.0,
#  'General Commercial Knowledge': 4.0,
#  'Spreadsheets for Business & Personal Productivity': 1.0}
#
# ************************************************************
#
# Rohan.raman17@iimv.ac.in
#
# katta.nija17@iimv.ac.in
# himanth.esarapu17@iimv.ac.in
# amit.maurya17@iimv.ac.in
# aadesh.fathwani17@iimv.ac.in
# adithya.gogikar17@iimv.ac.in
# {'Banking, Financial Markets and Systems': 5.0,
#  'Business Data Mining & Decision Models': 2.0,
#  'Consumer Behaviour': 4.3}
#
# ************************************************************
#
# himanth.esarapu17@iimv.ac.in
#
# Rohan.raman17@iimv.ac.in
# adithya.gogikar17@iimv.ac.in
# manish.namana17@iimv.ac.in
# katta.nija17@iimv.ac.in
# amit.maurya17@iimv.ac.in
# {'Brand Management': 5.0,
#  'Business Data Mining & Decision Models': 3.1,
#  'Corporate Strategy': 4.1,
#  'Financial Derivatives': 1.0,
#  'General Commercial Knowledge': 2.6,
#  'Management Control System': 1.0,
#  'Spreadsheets for Business & Personal Productivity': 1.5}
#
# ************************************************************
#
# ravindra.pal17@iimv.ac
#
# kundi.pavan17@iimv.ac.in
# kartheek.pochampally17@iimv.ac.in
# alankruta.patnaik17@iimv.ac.in
# nikhil.kumar17@iimv.ac.in
# brahmadeb.mukherjee17@iimv.ac.in
# {'Banking, Financial Markets and Systems': 5.0,
#  'Brand Management': 4.5,
#  'Business Data Mining & Decision Models': 3.7,
#  'Financial Derivatives': 3.1,
#  'General Commercial Knowledge': 3.5,
#  'Management Control System': 1.0,
#  'Spreadsheets for Business & Personal Productivity': 2.9}
#
# ************************************************************
#
# sabhapathi.reddy17@iimv.ac.in
#
# tanmoy.misra17@iimv.ac.in
# elakkiya.n17@iimv.ac.in
# Shanthan.nimmagadda17@iimv.ac.in
# manish.namana17@iimv.ac.in
# sriharsha.palvadi17@iimv.ac.in
# {'Brand Management': 5.0,
#  'Business Data Mining & Decision Models': 4.0,
#  'Corporate Strategy': 3.6,
#  'Financial Derivatives': 1.0,
#  'General Commercial Knowledge': 1.9,
#  'Management Control System': 1.0,
#  'Spreadsheets for Business & Personal Productivity': 2.4}
#
# ************************************************************
#
# manish.namana17@iimv.ac.in
#
# sabhapathi.reddy17@iimv.ac.in
# elakkiya.n17@iimv.ac.in
# Shanthan.nimmagadda17@iimv.ac.in
# himanth.esarapu17@iimv.ac.in
# katta.nija17@iimv.ac.in
# {}
#
# ************************************************************
#
# rahul.singh17@iimv.ac.in
#
# tanmoy.misra17@iimv.ac.in
# sumeet.kumar17@iimv.ac.in
# sriharsha.palvadi17@iimv.ac.in
# saikam.raghava17@iimv.ac.in
# sabhapathi.reddy17@iimv.ac.in
# {'Business Data Mining & Decision Models': (0, [0.0]),
#  'Consumer Behaviour': (0, [0.0, 0.0, 0.0]),
#  'Corporate Strategy': (0, [0.0])}
#
# ************************************************************
#
# sumeet.kumar17@iimv.ac.in
#
# tanmoy.misra17@iimv.ac.in
# sriharsha.palvadi17@iimv.ac.in
# saikam.raghava17@iimv.ac.in
# sabhapathi.reddy17@iimv.ac.in
# ravindra.pal17@iimv.ac
# {'Corporate Strategy': (0, [0.0, 0.0]),
#  'General Commercial Knowledge': (0, [0.0]),
#  'Spreadsheets for Business & Personal Productivity': (0, [0.0])}
#
# ************************************************************
#
# brahmadeb.mukherjee17@iimv.ac.in
#
# arnav.sharma17@iimv.ac.in
# tanmoy.misra17@iimv.ac.in
# katta.nija17@iimv.ac.in
# amit.maurya17@iimv.ac.in
# aadesh.fathwani17@iimv.ac.in
# {'Business Data Mining & Decision Models': 2.0,
#  'Consumer Behaviour': 4.0,
#  'Corporate Strategy': 4.5}
#
# ************************************************************
#
# kundi.pavan17@iimv.ac.in
#
# ravindra.pal17@iimv.ac
# amit.maurya17@iimv.ac.in
# manish.namana17@iimv.ac.in
# kartheek.pochampally17@iimv.ac.in
# tanmoy.misra17@iimv.ac.in
# {'B2B Marketing': 3.9,
#  'Banking, Financial Markets and Systems': 5.0,
#  'Brand Management': 5.0,
#  'Management Control System': 1.0,
#  'Project Management': 3.9,
#  'Research for Marketing Decisions': 4.5,
#  'Spreadsheets for Business & Personal Productivity': 1.6}
#
# ************************************************************
